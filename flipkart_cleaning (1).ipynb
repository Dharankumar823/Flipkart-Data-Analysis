# %%
#!pip install openpyxl
import pandas as pd
df=pd.read_csv("flikart_webscrap.csv")
df
# Out:
#      Unnamed: 0  stars          ratings discounts     prices        brand  \
# 0             0    4.2   6,171 Ratings    48% off  â‚¹13,990       Godrej
# 1             1    4.3   2,379 Ratings    32% off  â‚¹11,548        Lloyd
# 2             2    4.3  86,950 Ratings    21% off  â‚¹28,590          IFB
# 3             3    4.3  79,969 Ratings    20% off  â‚¹17,990      SAMSUNG
# 4             4    4.3  86,950 Ratings    26% off  â‚¹33,990          IFB
# ..          ...    ...              ...       ...        ...          ...
# 378         378    4.4     608 Ratings    19% off  â‚¹13,400       Godrej
# 379         379    4.4     165 Ratings    21% off  â‚¹14,800      SAMSUNG
# 380         380    4.0     231 Ratings    39% off  â‚¹16,990       Godrej
# 381         381    NaN              NaN   22% off  â‚¹23,349    Whirlpool
# 382         382    3.9      27 Ratings    41% off  â‚¹11,199  Voltas Beko
#
#     energy_rating  capacity max_spin_speed
# ...

# %%
mask=df["capacity"].apply(lambda x:len(x)<7)
len(df[mask])
# Out:
# 352

# %%
df2 = df[mask]
df2.shape
# Out:
# (352, 9)

# %%
df2
# Out:
#      Unnamed: 0  stars          ratings discounts     prices        brand  \
# 0             0    4.2   6,171 Ratings    48% off  â‚¹13,990       Godrej
# 1             1    4.3   2,379 Ratings    32% off  â‚¹11,548        Lloyd
# 2             2    4.3  86,950 Ratings    21% off  â‚¹28,590          IFB
# 3             3    4.3  79,969 Ratings    20% off  â‚¹17,990      SAMSUNG
# 4             4    4.3  86,950 Ratings    26% off  â‚¹33,990          IFB
# ..          ...    ...              ...       ...        ...          ...
# 377         377    4.5       4 Ratings    15% off  â‚¹21,100      SAMSUNG
# 379         379    4.4     165 Ratings    21% off  â‚¹14,800      SAMSUNG
# 380         380    4.0     231 Ratings    39% off  â‚¹16,990       Godrej
# 381         381    NaN              NaN   22% off  â‚¹23,349    Whirlpool
# 382         382    3.9      27 Ratings    41% off  â‚¹11,199  Voltas Beko
#
#     energy_rating capacity max_spin_speed
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 352 entries, 0 to 382
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      352 non-null    int64
#  1   stars           347 non-null    float64
#  2   ratings         341 non-null    object
#  3   discounts       349 non-null    object
#  4   prices          352 non-null    object
#  5   brand           352 non-null    object
#  6   energy_rating   352 non-null    object
#  7   capacity        352 non-null    object
#  8   max_spin_speed  352 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 27.5+ KB

# %%
df2 = df2.copy()
df2.dropna(axis=0, inplace=True)
df2
# Out:
#      Unnamed: 0  stars          ratings discounts     prices        brand  \
# 0             0    4.2   6,171 Ratings    48% off  â‚¹13,990       Godrej
# 1             1    4.3   2,379 Ratings    32% off  â‚¹11,548        Lloyd
# 2             2    4.3  86,950 Ratings    21% off  â‚¹28,590          IFB
# 3             3    4.3  79,969 Ratings    20% off  â‚¹17,990      SAMSUNG
# 4             4    4.3  86,950 Ratings    26% off  â‚¹33,990          IFB
# ..          ...    ...              ...       ...        ...          ...
# 375         375    4.3   2,758 Ratings    23% off  â‚¹18,798    Whirlpool
# 377         377    4.5       4 Ratings    15% off  â‚¹21,100      SAMSUNG
# 379         379    4.4     165 Ratings    21% off  â‚¹14,800      SAMSUNG
# 380         380    4.0     231 Ratings    39% off  â‚¹16,990       Godrej
# 382         382    3.9      27 Ratings    41% off  â‚¹11,199  Voltas Beko
#
#     energy_rating capacity max_spin_speed
# ...

# %%
df2.replace({
    'ratings':'[ Ratings]',
    'prices':'[â‚¹]',
    'capacity':[' Kg',' kg'],
    'max_spin_speed':[' rpm',' RPM']
},'',regex=True,inplace=True)
df2
# Out:
#      Unnamed: 0  stars ratings discounts  prices        brand energy_rating  \
# 0             0    4.2   6,171   48% off  13,990       Godrej             5
# 1             1    4.3   2,379   32% off  11,548        Lloyd             5
# 2             2    4.3  86,950   21% off  28,590          IFB             5
# 3             3    4.3  79,969   20% off  17,990      SAMSUNG             5
# 4             4    4.3  86,950   26% off  33,990          IFB             5
# ..          ...    ...     ...       ...     ...          ...           ...
# 375         375    4.3   2,758   23% off  18,798    Whirlpool             5
# 377         377    4.5       4   15% off  21,100      SAMSUNG             5
# 379         379    4.4     165   21% off  14,800      SAMSUNG             5
# 380         380    4.0     231   39% off  16,990       Godrej             5
# 382         382    3.9      27   41% off  11,199  Voltas Beko             5
#
#     capacity max_spin_speed
# ...

# %%
df2.replace({
    'ratings':'[,]',
    'prices':'[,]'
},'',regex=True,inplace=True)
df2
# Out:
#      Unnamed: 0  stars ratings discounts prices        brand energy_rating  \
# 0             0    4.2    6171   48% off  13990       Godrej             5
# 1             1    4.3    2379   32% off  11548        Lloyd             5
# 2             2    4.3   86950   21% off  28590          IFB             5
# 3             3    4.3   79969   20% off  17990      SAMSUNG             5
# 4             4    4.3   86950   26% off  33990          IFB             5
# ..          ...    ...     ...       ...    ...          ...           ...
# 375         375    4.3    2758   23% off  18798    Whirlpool             5
# 377         377    4.5       4   15% off  21100      SAMSUNG             5
# 379         379    4.4     165   21% off  14800      SAMSUNG             5
# 380         380    4.0     231   39% off  16990       Godrej             5
# 382         382    3.9      27   41% off  11199  Voltas Beko             5
#
#     capacity max_spin_speed
# 0          7            720
# ...

# %%
df2.ratings=df2.ratings.astype(int)

# %%
df2.ratings.dtype
# Out:
# dtype('int64')

# %%
df2.prices=df2.prices.astype(int)

# %%
df2.prices.dtype
# Out:
# dtype('int64')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 339 entries, 0 to 382
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      339 non-null    int64
#  1   stars           339 non-null    float64
#  2   ratings         339 non-null    int64
#  3   discounts       339 non-null    object
#  4   prices          339 non-null    int64
#  5   brand           339 non-null    object
#  6   energy_rating   339 non-null    object
#  7   capacity        339 non-null    object
#  8   max_spin_speed  339 non-null    object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 26.5+ KB

# %%
df2.capacity.unique()
# Out:
# array(['7', '7.5', '8', '8.5', '6.5', '9.5', '9', '6', '10', '14', '11',
#        '12', 'Tumble', '5.5'], dtype=object)

# %%
MASK=df2.capacity!="Tumble"
MASK.sum()
# Out:
# np.int64(338)

# %%
df3=df2[MASK]

# %%
df3 = df3.copy()

# %%
df3.capacity=df3.capacity.astype(float)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 338 entries, 0 to 382
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      338 non-null    int64
#  1   stars           338 non-null    float64
#  2   ratings         338 non-null    int64
#  3   discounts       338 non-null    object
#  4   prices          338 non-null    int64
#  5   brand           338 non-null    object
#  6   energy_rating   338 non-null    object
#  7   capacity        338 non-null    float64
#  8   max_spin_speed  338 non-null    object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 26.4+ KB

# %%
df3.energy_rating.unique()
# Out:
# array(['5', '4', '1'], dtype=object)

# %%
df3['energy_rating'] = df3['energy_rating'].astype(int)

# %%
df3.energy_rating.dtype
# Out:
# dtype('int64')

# %%
df3.max_spin_speed.unique()
# Out:
# array(['720', '1300', '1200', '700', '1400', '1440', '1000', '740',
#        '1350', '702', '1500', '650', '1450', '800', '750', '680', '900',
#        '840', '780', '1360', '1380', 'Yes', '1490'], dtype=object)

# %%
MASK=df3.max_spin_speed!="Yes"
MASK.sum()
# Out:
# np.int64(337)

# %%
df4=df3[MASK]

# %%
df4 = df4.copy()

# %%
df4.max_spin_speed=df4.max_spin_speed.astype(int)

# %%
df4.max_spin_speed.dtype
# Out:
# dtype('int64')

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 337 entries, 0 to 382
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      337 non-null    int64
#  1   stars           337 non-null    float64
#  2   ratings         337 non-null    int64
#  3   discounts       337 non-null    object
#  4   prices          337 non-null    int64
#  5   brand           337 non-null    object
#  6   energy_rating   337 non-null    int64
#  7   capacity        337 non-null    float64
#  8   max_spin_speed  337 non-null    int64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 26.3+ KB

# %%
df4
# Out:
#      Unnamed: 0  stars  ratings discounts  prices        brand  energy_rating  \
# 0             0    4.2     6171   48% off   13990       Godrej              5
# 1             1    4.3     2379   32% off   11548        Lloyd              5
# 2             2    4.3    86950   21% off   28590          IFB              5
# 3             3    4.3    79969   20% off   17990      SAMSUNG              5
# 4             4    4.3    86950   26% off   33990          IFB              5
# ..          ...    ...      ...       ...     ...          ...            ...
# 375         375    4.3     2758   23% off   18798    Whirlpool              5
# 377         377    4.5        4   15% off   21100      SAMSUNG              5
# 379         379    4.4      165   21% off   14800      SAMSUNG              5
# 380         380    4.0      231   39% off   16990       Godrej              5
# 382         382    3.9       27   41% off   11199  Voltas Beko              5
#
#      capacity  max_spin_speed
# ...

# %%
df4.to_csv("flikpart_cleaned_data_for_bi.csv",index=False)
